# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h4>Roll No. : 208</b></center>
# <center><b><h4>Name : Vrinda Siddhpura</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import calc

a = calc.add(2,2)
print(a)

b = calc.sub(2,1)
print(b)

c = calc.mul(2,2)
print(c)

d = calc.div(2,2)
print(d)
# Out:
# 4
# 1
# 4
# 1.0

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random

string = 'abcdefghijk'

random.choices(string)
# Out:
# ['i']

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
import random

li = [1, 2, 3, 4, 5]

random.choices(li)
# Out:
# [5]

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
import random
random.seed(0)
n = random.randrange(1,7)
print(n)
# Out:
# 4

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
import random

li = list(range(100, 1000, 5))

random.choices(li, k=3)
# Out:
# [805, 370, 525]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
import random

li = list(range(1, 101))

print(f'Winner is {random.sample(li, k=1)} and Runner up is {random.sample(li, k=1)}')
# Out:
# Winner is [28] and Runner up is [65]

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2026-03-02 10:48:37.972783

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
import datetime

print(datetime.date.today() - datetime.timedelta(days = 7))
# Out:
# 2026-02-23

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
import datetime

d1 = datetime.date(2026, 1, 1)
d2 = datetime.date(2026, 2, 1)

print(d2 - d1)
# Out:
# 31 days, 0:00:00

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
import datetime

print(f'Date: {datetime.date.today()} and Day: {datetime.date.today().strftime("%A")}')
# Out:
# Date: 2026-03-02 and Day: Monday
