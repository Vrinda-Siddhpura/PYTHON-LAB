# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
a = int(input("Enter Number:"))

if a>0:
    print("Positive")
elif a<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter Number: -5
# Negative

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
a = int(input("Enter Number:"))

if a%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter Number: 5
# Odd

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
a = int(input("Enter first Number:"))
b = int(input("Enter second Number:"))

if a>b:
    print(f"Largest number is {a}")
else:
    print(f"Largest number is {b}")

# c = a if a>b else b
# print(f'Largest number is {c}')
# Out:
# Enter first Number: 2
# Enter second Number: 5
# Largest number is 5

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
a = int(input("Enter first Number:"))
b = int(input("Enter second Number:"))
c = int(input("Enter third Number:"))

temp1 = a if a>b else b
temp2 = temp1 if temp1>c else c

# d =  a if(a > b and a > c) else b if(b > a and b > c) else c

print(f'Largest number is {temp2}')
# Out:
# Enter first Number: 2
# Enter second Number: 7
# Enter third Number: 9
# Largest number is 9

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# #### [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input("Enter Year:"))

if (year%4==0 and year%100!=0) or year%400==0:
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Enter Year: 2023
# Not Leap Year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
a = int(input("Enter (1-7) Number:"))

if a%7==1:
    print("Sunday")
elif a%7==2:
    print("Monday")
elif a%7==3:
    print("Tuesday")
elif a%7==4:
    print("Wednesday")
elif a%7==5:
    print("Thurday")
elif a%7==6:
    print("Friday")
else:
    print("Saturday")
# Out:
# Enter (1-7) Number: 6
# Friday

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
a = int(input("Enter first Number:"))
b = int(input("Enter second Number:"))
sign = input("Enter task")

match sign:
    case '+':
        print(f'{a+b}')
    case '-':
        print(f'{a-b}')
    case '*':
        print(f'{a*b}')
    case '/':
        print(f'{a/b}')
# Out:
# Enter first Number: 2
# Enter second Number: 4
# Enter task +
# 6

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# #### Fail below 35
# #### Pass Class between 35 to 45
# #### Second Class
# #### between 45 to 60
# #### First Class between 60 to 70
# #### Distinction if more than 70

# %%
a = int(input("Enter first mark:"))
b = int(input("Enter second mark:"))
c = int(input("Enter third mark:"))
d = int(input("Enter fourth mark:"))
e = int(input("Enter fifth mark:"))

percentage = (a+b+c+d+e)/5

if percentage<35:
    print("Fail")
elif percentage>35 and percentage<45:
    print("Pass")
elif percentage>45 and percentage<60:
    print("Second Class")
elif percentage>60 and percentage<70:
    print("First Class")
else:
    print("Distinction")
# Out:
# Enter first mark: 88
# Enter second mark: 88
# Enter third mark: 88
# Enter fourth mark: 88
# Enter fifth mark: 88
# Distinction

# %% [markdown]
# ### 09) WAP to find the second largest number among three user input numbers.

# %%
a = int(input("Enter first Number:"))
b = int(input("Enter second Number:"))
c = int(input("Enter third Number:"))

if (a>b and a<c) or (a<b and a>c):
    print(f'Second largest number {a}')
elif (b>a and b<c) or (b<a or b>c):
    print(f'Second largest number {b}')
else:
    print(f'Second largest number {c}')
# Out:
# Enter first Number: 7
# Enter second Number: 10
# Enter third Number: 6
# Second largest number 7

# %% [markdown]
# ### 10) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# #### a. First 1 to 50 units – Rs. 2.60/unit
# #### b. Next 50 to 100 units – Rs. 3.25/unit
# #### c. Next 100 to 200 units – Rs. 5.26/unit
# #### d. above 200 units – Rs. 8.45/unit

# %%
a = int(input("Enter Units:"))

if a<=50:
    bill = a*2.60
elif a<=100:
    bill = 50*2.60 + (a-50)*3.25
elif a<=200:
    bill = 50*2.60 + (a-50)*3.25 + (a-100)*5.26
else:
    bill =  50*2.60 + (a-50)*3.25 + (a-100)*5.26 + (a-200)*8.45

print(bill)
# Out:
# Enter Units: 70
# 195.0
