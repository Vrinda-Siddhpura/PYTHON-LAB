# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
# <center><b><h4>Roll No. : 208</b></center>
# <center><b><h4>Name : Vrinda Siddhpura</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
fp = open("file1.txt")
print(fp.read())
fp.seek(0)
print(fp.readline())
fp.seek(0)
print(fp.readlines())
fp.close()
# Out:
# Hello World!
# Heyy
# Hello World!
#
# ['Hello World!\n', 'Heyy']

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
s = "Hello World!!"
fp = open("new.txt", "w")
print(fp.write(s))
fp.close()
# Out:
# 13

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
fp = open("file1.txt")
li = fp.readlines()
print(li[0:5])
fp.close()
# Out:
# ['Hello World!\n', 'Heyy\n', 'Hii\n', 'Hehe\n', 'How Are You?\n']

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file.

# %%
fp = open("file1.txt")
li = fp.read()
data = li.split()
max = len(li[0])
for i in data:
    if max<len(i):
        max = len(i)
print(max)

li =[]
for i in data:
    if len(i) == max:
        print(i)
fp.close()
# Out:
# 8
# Hiiiiiii

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
fp = open("file1.txt")

count1 = 0
li = fp.readlines()
print(f'Number of lines: {len(li)}')

fp.seek(0)
print(f'Number of words: {len(fp.read().split())}')

fp.seek(0)
print(f'Number of characters: {len(fp.read())}')

fp.close()
# Out:
# Number of lines: 6
# Number of words: 9
# Number of characters: 48

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %%
fp1 = open("file1.txt")
s = fp1.read()

fp2 = open("new.txt", "w")
fp2.write(s)

fp1.close()
fp2.close()

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
fp = open("file1.txt")
li = fp.read()
print(len(li))
fp.close()
# Out:
# 52

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
def frequency(target_word):
    count = 0
    fp = open("file1.txt")
    li = fp.read().split()
    for i in li:
        if i.lower() == target_word.lower():
            count += 1 
    fp.close()
    return count
    
target_word = input("Enter word to search:")

res = frequency(target_word)
print(res)
# Out:
# Enter word to search: Hii
# 2

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
li = []
for i in range(5):
    li.append(int(input("Enter Marks:")))

fp = open("new.txt", "w")
li = list(map(str,li))
fp.write(" ".join(li))
fp.close()

fp1 = open("new.txt")
max = li[0]
for i in li:
    if max<i:
        max = i
print(f'Hieghest Mark: {max}')

fp.close()
fp1.close()
# Out:
# Enter Marks: 12
# Enter Marks: 77
# Enter Marks: 55
# Enter Marks: 33
# Enter Marks: 88
# Hieghest Mark: 88

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %%
fp = open("primenumbers.txt", "w")

for i in range(1,101):
    count = 0
    for j in range(1,i+1):
        if i%j==0:
            count += 1

    if count==2:
        fp.write(str(i) + '\n')

fp.close()

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %%
fp1 = open("file1.txt")
data1 = fp1.read()

fp2 = open("primenumbers.txt")
data2 = fp2.read()

fp3 = open("new.txt", "w")
fp3.write(data1)
fp3.write('\n')
fp3.write(data2)

fp1.close()
fp2.close()
fp3.close()

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %%
word1 = input("Enter word1:")
word2 = input("Enter word2:")

fp1 = open("file1.txt")
li = fp1.readlines()
li2 = [i.replace(word1, word2) for i in li]

fp2 = open("new.txt", "w")
fp2.writelines(li2)

fp1.close()
fp2.close()
# Out:
# Enter word1: Hello World!
# Enter word2: How Are You?

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.

# %%
fp = open("file1.txt")

fp.seek(0,0)
print("Current Position:", fp.tell())
print("Found:", fp.read(12))

fp.close()

fp1 = open("file1.txt", "rb")

fp1.seek(6,1)
print("Current Position:", fp1.tell())
print("Found:", fp1.read(6))

fp1.seek(-8,2)
print("Current Position:", fp1.tell())
print("Found:", fp1.read(8))
# Out:
# Current Position: 0
# Found: Hello World!
# Current Position: 6
# Found: b'World!'
# Current Position: 44
# Found: b'Hiiiiiii'
